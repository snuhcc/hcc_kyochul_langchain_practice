# %%
! pip install langchain-chroma langchain_community tiktoken langchain-openai langchainhub langchain langgraph tavily-python
# Out:
# Collecting langchain-chroma
#   Using cached langchain_chroma-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain_community in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (0.2.9)
# Requirement already satisfied: tiktoken in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (0.7.0)
# Requirement already satisfied: langchain-openai in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (0.1.17)
# Requirement already satisfied: langchainhub in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (0.1.20)
# Requirement already satisfied: langchain in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (0.2.10)
# Collecting langgraph
#   Downloading langgraph-0.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting tavily-python
#   Downloading tavily_python-0.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-chroma) (0.5.3)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-chroma) (0.110.1)
# Requirement already satisfied: langchain-core<0.3,>=0.1.40 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-chroma) (0.2.22)
# Requirement already satisfied: numpy<2,>=1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (0.1.93)
# Requirement already satisfied: requests<3,>=2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain_community) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain_community)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-openai) (1.37.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchainhub) (24.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain) (1.10.14)
# Collecting langchain-core<0.3,>=0.1.40 (from langchain-chroma)
#   Downloading langchain_core-0.2.29-py3-none-any.whl.metadata (6.2 kB)
# Collecting langgraph-checkpoint<2.0.0,>=1.0.2 (from langgraph)
#   Downloading langgraph_checkpoint-1.0.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: httpx in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from tavily-python) (0.27.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: build>=1.0.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.29.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.62.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.37.2)
# Requirement already satisfied: anyio in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpx->tavily-python) (4.2.0)
# Requirement already satisfied: certifi in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpx->tavily-python) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpx->tavily-python) (1.0.5)
# Requirement already satisfied: idna in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpx->tavily-python) (3.7)
# Requirement already satisfied: sniffio in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpx->tavily-python) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from httpcore==1.*->httpx->tavily-python) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma) (1.33)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from anyio->httpx->tavily-python) (1.2.0)
# Requirement already satisfied: pyproject_hooks in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.0.1)
# Requirement already satisfied: tomli>=1.1.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.40->langchain-chroma) (2.4)
# Requirement already satisfied: six>=1.9.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: coloredlogs in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: protobuf in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.25.3)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (60.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.24.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from importlib-resources->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: filelock in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2024.6.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/kyochul_jang/opt/anaconda3/envs/aimers/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.0)
# Downloading langchain_chroma-0.1.2-py3-none-any.whl (9.3 kB)
# Downloading langgraph-0.2.2-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 142.5 kB/s eta 0:00:00 kB/s eta 0:00:01
# Downloading tavily_python-0.3.6-py3-none-any.whl (13 kB)
# Downloading langchain_core-0.2.29-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 kB 451.6 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Downloading langgraph_checkpoint-1.0.2-py3-none-any.whl (14 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 500.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, tenacity, sympy, tavily-python, langchain-core, langgraph-checkpoint, langgraph, langchain-chroma
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.22
#     Uninstalling langchain-core-0.2.22:
#       Successfully uninstalled langchain-core-0.2.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.0.1 requires networkx, which is not installed.
# torchvision 0.15.2 requires pillow!=8.3.*,>=5.3.0, which is not installed.
# Successfully installed langchain-chroma-0.1.2 langchain-core-0.2.29 langgraph-0.2.2 langgraph-checkpoint-1.0.2 mpmath-1.3.0 sympy-1.13.1 tavily-python-0.3.6 tenacity-8.5.0
